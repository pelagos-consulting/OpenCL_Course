# %% [markdown]
# # Debugging OpenCL applications
#
# Debugging OpenCL kernels has in the past been difficult due to a lack of vendor support. However there are some tools and techniques to help, such as:
#
# * Checking the error codes on every OpenCL function call
# * Checking memory access from within kernels
# * Visual inspection of outputs
# * Using **printf** within kernels
# * Using **Oclgrind** to check memory access violations
# * Vendor-specific tools
#
# We introduce an **bug** into our matrix multiplication kernel and see what techniques can uncover the error. In this instance we **intentionally remove** the guard check that protects the kernel from setting values outside the domain of **C**. The size of matrices **A**, **B**, and **C** are set to (72,72) with a local size of (4,16). Along dimension 0 an exact number of workgroups (18) can fit into the desired local size of 72. However, along dimension 1 the global size must be increased to 80 in order for an integer number of workgroups to fit. If we do not have a guard in place, then array accesses into the matrices will run off the ends, resulting in a memory access violation.
#
# <figure style="margin-left:auto; margin-right:auto; width:80%;">
#     <img style="vertical-align:middle" src="../images/matrix_boundaries.svg">
#     <figcaption style= "text-align:lower; margin:1em; float:bottom; vertical-align:bottom;">Running off the end of the array due to differences between array size and global size.</figcaption>
# </figure>
#
# ```C++
# // kernels_mat_mult_badmem.c source
#
# // standard matrix multiply kernel
# __kernel void mat_mult (__global float* A,
#                         __global float* B,
#                         __global float* C,
#                         unsigned int N1_A,
#                         unsigned int N0_C,
#                         unsigned int N1_C) {
#
#     // C is of size (N0_C, N1_C)
#
#     // i0 and i1 represent the coordinates in Matrix C
#     // We assume row-major ordering for the matrices
#     size_t i0=get_global_id(0);
#     size_t i1=get_global_id(1);
#
#     // Scratch variable
#     float temp=0.0;
#
#     // Guard mechanism to make sure we do not go
#     // outside the boundaries of matrix C
#
#     // Comment out the if statement
#     // that normally ensures we do not go
#     // outside the boundaries of matrix C
#
#     //if ((i0<N0_C) && (i1<N1_C)) {
#         // Loop over columns of A and rows of B
#         for (size_t n=0; n<N1_A; n++) {
#
#             // A is of size (N0_C, N1_A)
#             // B is of size (N1_A, N1_C)
#
#             // Loop across row i0 of A
#             // and down column i1 of B
#             temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#         }
#         // Number of rows in C is same as number of rows in A
#         C[i0*N1_C+i1]=temp;
#     //}
# }
# ```

# %% [markdown]
# ## Construct inputs
#
# As before construct the arrays for input.

# %%
import os
import sys
import numpy as np
sys.path.insert(0, os.path.abspath("../include"))

import py_helper

# %matplotlib widget

# Data type to use for matrices
dtype=np.float32

defines=py_helper.load_defines("mat_size.hpp")

NCOLS_A=defines["NCOLS_A"]
NROWS_C=defines["NROWS_C"]
NCOLS_C=defines["NCOLS_C"]

# A is of size (NROWS_C, NCOLS_A)
# B is of size (NCOLS_A, NCOLS_C)    
# C is of size (NROWS_C, NCOLS_C)

mat_mul=py_helper.MatMul(NCOLS_A, NROWS_C, NCOLS_C, dtype)
mat_mul.make_data()

# %% [markdown]
# ## Run the buggy application

# %%
# !make clean; make;  ./mat_mult_badmem.exe -gpu
# Out:
# rm -r *.exe
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_mult.cpp\
# 	-o mat_mult.exe -lOpenCL
# In file included from mat_mult.cpp:19:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_mult.cpp:19:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_mult_memcheck.cpp\
# 	-o mat_mult_memcheck.exe -lOpenCL
# In file included from mat_mult_memcheck.cpp:14:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_mult_memcheck.cpp:14:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_mult_badmem.cpp\
# 	-o mat_mult_badmem.exe -lOpenCL
# In file included from mat_mult_badmem.cpp:14:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_mult_badmem.cpp:14:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_mult_printf.cpp\
# 	-o mat_mult_printf.exe -lOpenCL
# In file included from mat_mult_printf.cpp:14:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_mult_printf.cpp:14:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_mult_badmem_gdb.cpp\
# 	-o mat_mult_badmem_gdb.exe -lOpenCL
# In file included from mat_mult_badmem_gdb.cpp:14:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_mult_badmem_gdb.cpp:14:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_elementwise_buggy.cpp\
# 	-o mat_elementwise_buggy.exe -lOpenCL
# In file included from mat_elementwise_buggy.cpp:15:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_elementwise_buggy.cpp:15:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++11 -g -O2 -fopenmp -O0 -I/usr/include -I../include -L/usr/lib/x86_64-linux-gnu mat_elementwise_answer.cpp\
# 	-o mat_elementwise_answer.exe -lOpenCL
# In file included from mat_elementwise_answer.cpp:15:
# ../include/cl_helper.hpp: In function ‘_cl_command_queue** h_create_command_queues(_cl_device_id**, _cl_context**, cl_uint, cl_uint, cl_bool, cl_bool)’:
# ../include/cl_helper.hpp:332:49: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   332 |         command_queues[n] = clCreateCommandQueue(
#       |                             ~~~~~~~~~~~~~~~~~~~~^
#   333 |             contexts[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   334 |             devices[n % num_devices],
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~
#   335 |             queue_properties,
#       |             ~~~~~~~~~~~~~~~~~
#   336 |             &errcode
#       |             ~~~~~~~~
#   337 |         );
#       |         ~
# In file included from ../include/CL/opencl.h:24,
#                  from ../include/cl_helper.hpp:25,
#                  from mat_elementwise_answer.cpp:15:
# ../include/CL/cl.h:1913:1: note: declared here
#  1913 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# 	               name: NVIDIA GeForce RTX 3060 Laptop GPU
# 	 global memory size: 6235 MB
# 	    max buffer size: 1558 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024

# %% [markdown]
# Notice that with some OpenCL implementations the code completes without crashing. This is because some OpenCL frameworks (GPU ones in particular) do not have stringent memory access violation checks. Memory access violations can result in undefined behaviour. Due to OS security, CPU implementations are more sensitive to memory access violations than GPU implementations, where memory allocations may be padded and memory access violations are not as protected.

# %% [markdown]
# ## Visual inspection of outputs

# %%
mat_mul.check_data()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# The effect of the memory error is noticeable when we perform a direct comparison between Python and our OpenCL application. Row 0 of the of the output is unaffected, however all subsequent rows are affected by the bug because for each row the kernel spills over to 8 cells of the next row. At the last row is when a memory access violation occurs because then it runs off the end of the array.

# %% [markdown]
# ## Checking OpenCL calls
#
# Inspecting the return codes of OpenCL calls is good practice for programming with OpenCL. Many API errors are caught this way. In this lesson we have already checked return codes and they haven't signalled an error. We need to dig deeper....

# %% [markdown]
# ## Checking memory access by filling with known values
#
# When trying to get your OpenCL codes working it is helpful to first make sure that your memory accesses are valid. In this instance we change the kernel to [kernels_mat_mult_memcheck.c](kernels_mat_mult_memcheck.c) so that it fills **C** with a known value. In this case we fill it with **i1**. Run the code and check the results by running the visual check above.

# %%
# !make; ./mat_mult_memcheck.exe
# Out:
# make: Nothing to be done for 'all'.
# 	               name: Intel(R) FPGA Emulation Device
# 	 global memory size: 32878 MB
# 	    max buffer size: 16439 MB
# 	     max local size: (67108864,67108864,67108864)
# 	     max work-items: 67108864

# %% [markdown]
# In the visual check some lines are filled with higher values of **i1** whereas others are filled with lower values. This is because in the buggy implementation two different kernel invocations are writing to the same global memory location. This illustrates that one cannot rely on the order in which workgroups complete and the order in which memory updates are flushed back to global memory.

# %% [markdown]
# ## Debugging with **printf**
#
# Most of the major OpenCL implementations, including POCL, NVIDIA, AMD, and INTEL allow the use of a **printf** statement within a kernel. Output from printf in the kernel gets routed to standard output on the command line. We edit the kernel source in file [kernels_mat_mult.c](kernels_mat_mult.c) to include a printf statement that triggers whenever we exceed the size of the matrices along dimension 1.
#
# ```C
# // Kernel with printf statement
# __kernel void mat_mult_printf (__global float* A,
#                         __global float* B,
#                         __global float* C,
#                         unsigned int N1_A,
#                         unsigned int N0_C,
#                         unsigned int N1_C) {
#
#     // C is of size (N0_C, N1_C)
#
#     // i0 and i1 represent the coordinates in Matrix C
#     // We assume row-major ordering for the matrices
#     size_t i0=get_global_id(0);
#     size_t i1=get_global_id(1);
#
#     // Scratch variable
#     float temp=0.0;
#
#     // Comment out the guard mechanism
#     // to make sure we do not go
#     // outside the boundaries of matrix C
#     if ((i1>N1_C-1) && (i0==0)) {
#         printf("i1 is %d\n", (int)i1);
#     }
#
#     //if ((i0<N0_C) && (i1<N1_C)) {
#         // Loop over columns of A and rows of B
#         for (size_t n=0; n<N1_A; n++) {
#
#             // A is of size (N0_C, N1_A)
#             // B is of size (N1_A, N1_C)
#
#             // Loop across row i0 of A
#             // and down column i1 of B
#             temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#         }
#         // Number of rows in C is same as number of rows in A
#         C[i0*N1_C+i1]=temp;
#     //}
# }
# ```

# %% [markdown]
# Now run the program and observe that the workgroups do indeed encounter values of **i1** that go beyond the bounds of the array.

# %%
# !make; ./mat_mult_printf.exe -cpu
# Out:
# make: Nothing to be done for 'all'.
# 	               name: AMD Ryzen 7 6800H with Radeon Graphics
# 	 global memory size: 32878 MB
# 	    max buffer size: 16439 MB
# 	     max local size: (8192,8192,8192)
# 	     max work-items: 8192
# i1 is 72
# i1 is 73
# i1 is 74
# i1 is 75
# i1 is 76
# i1 is 77
# i1 is 78
# i1 is 79

# %% [markdown]
# ## Debugging and validation with Oclgrind
#
# [Oclgrind](https://github.com/jrprice/Oclgrind) simulates an OpenCL device that self-checks for data races, memory access violations, and erroneous API runtime calls. It currently provides an OpenCL 1.2 interface as well as **gdb-like** interactive kernel debugging. Oclgrind is exactly what the OpenCL community needs for interactive debugging of kernels, however it is **orders of magnitude** slower than a native OpenCL application, so you need to make problem sizes really small, as we have done, or you can have a setting **-q** to just compute the first and last workgroups.

# %% [markdown]
# ### Memory access checking
#
# If you run **oclgrind** with the application as an argument then it intercepts OpenCL library calls that the application makes, and provides a sole OpenCL device that checks for errors.

# %%
# !oclgrind ./mat_mult_badmem.exe
# Out:
# 	               name: Oclgrind Simulator
# 	 global memory size: 134 MB
# 	    max buffer size: 134 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 1024
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,72,0) Local(0,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,72,0) Local(1,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,72,0) Local(2,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,72,0) Local(3,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(0,72,0) Local(0,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,73,0) Local(0,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(1,72,0) Local(1,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,73,0) Local(1,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(2,72,0) Local(2,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,73,0) Local(2,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(3,72,0) Local(3,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,73,0) Local(3,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(0,73,0) Local(0,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,74,0) Local(0,10,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(1,73,0) Local(1,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,74,0) Local(1,10,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(2,73,0) Local(2,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,74,0) Local(2,10,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,74,0) Local(3,10,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(3,73,0) Local(3,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,75,0) Local(0,11,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(8,72,0) Local(0,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(0,74,0) Local(0,10,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,75,0) Local(1,11,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(9,72,0) Local(1,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(1,74,0) Local(1,10,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,75,0) Local(2,11,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(10,72,0) Local(2,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(2,74,0) Local(2,10,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,75,0) Local(3,11,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(11,72,0) Local(3,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(3,74,0) Local(3,10,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,76,0) Local(0,12,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(12,72,0) Local(0,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(8,73,0) Local(0,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(0,75,0) Local(0,11,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,76,0) Local(1,12,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(16,72,0) Local(0,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(13,72,0) Local(1,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,76,0) Local(2,12,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(1,75,0) Local(1,11,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(20,72,0) Local(0,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(24,72,0) Local(0,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(17,72,0) Local(1,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(9,73,0) Local(1,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,76,0) Local(3,12,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(14,72,0) Local(2,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(2,75,0) Local(2,11,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(25,72,0) Local(1,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(28,72,0) Local(0,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(21,72,0) Local(1,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(18,72,0) Local(2,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(10,73,0) Local(2,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,77,0) Local(0,13,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(15,72,0) Local(3,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(3,75,0) Local(3,11,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(26,72,0) Local(2,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(29,72,0) Local(1,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(22,72,0) Local(2,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(11,73,0) Local(3,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,77,0) Local(1,13,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(12,73,0) Local(0,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(27,72,0) Local(3,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(0,76,0) Local(0,12,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(30,72,0) Local(2,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(23,72,0) Local(3,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(36,72,0) Local(0,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,77,0) Local(2,13,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(19,72,0) Local(3,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(8,74,0) Local(0,10,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(40,72,0) Local(0,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(13,73,0) Local(1,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(24,73,0) Local(0,9,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(31,72,0) Local(3,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(1,76,0) Local(1,12,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(20,73,0) Local(0,9,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(37,72,0) Local(1,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(16,73,0) Local(0,9,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,77,0) Local(3,13,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(9,74,0) Local(1,10,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(32,72,0) Local(0,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(41,72,0) Local(1,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(14,73,0) Local(2,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(25,73,0) Local(1,9,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(21,73,0) Local(1,9,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(17,73,0) Local(1,9,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(2,76,0) Local(2,12,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,78,0) Local(0,14,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(10,74,0) Local(2,10,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(33,72,0) Local(1,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(42,72,0) Local(2,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(18,73,0) Local(2,9,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(22,73,0) Local(2,9,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(28,73,0) Local(0,9,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(38,72,0) Local(2,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(26,73,0) Local(2,9,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(11,74,0) Local(3,10,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(34,72,0) Local(2,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(3,76,0) Local(3,12,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,78,0) Local(1,14,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(19,73,0) Local(3,9,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(43,72,0) Local(3,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(44,72,0) Local(0,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(29,73,0) Local(1,9,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(23,73,0) Local(3,9,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(39,72,0) Local(3,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(27,73,0) Local(3,9,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(8,75,0) Local(0,11,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(48,72,0) Local(0,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(16,74,0) Local(0,10,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(6,78,0) Local(2,14,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(0,77,0) Local(0,13,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(35,72,0) Local(3,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(40,73,0) Local(0,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(15,73,0) Local(3,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(45,72,0) Local(1,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(9,75,0) Local(1,11,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(49,72,0) Local(1,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(36,73,0) Local(0,9,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(24,74,0) Local(0,10,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(17,74,0) Local(1,10,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(20,74,0) Local(0,10,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(7,78,0) Local(3,14,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(52,72,0) Local(0,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(32,73,0) Local(0,9,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(56,72,0) Local(0,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(10,75,0) Local(2,11,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(41,73,0) Local(1,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(12,74,0) Local(0,10,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(37,73,0) Local(1,9,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(1,77,0) Local(1,13,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(50,72,0) Local(2,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(46,72,0) Local(2,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(53,72,0) Local(1,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(25,74,0) Local(1,10,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(18,74,0) Local(2,10,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(21,74,0) Local(1,10,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(4,79,0) Local(0,15,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(30,73,0) Local(2,9,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(33,73,0) Local(1,9,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(57,72,0) Local(1,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(42,73,0) Local(2,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(47,72,0) Local(3,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(38,73,0) Local(2,9,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(13,74,0) Local(1,10,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(2,77,0) Local(2,13,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(26,74,0) Local(2,10,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(54,72,0) Local(2,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(51,72,0) Local(3,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(11,75,0) Local(3,11,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(43,73,0) Local(3,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(22,74,0) Local(2,10,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(31,73,0) Local(3,9,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(44,73,0) Local(0,9,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(5,79,0) Local(1,15,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(39,73,0) Local(3,9,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(58,72,0) Local(2,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(14,74,0) Local(2,10,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult_badmem
# 	Entity: Global(34,73,0) Local(2,9,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult_badmem
# 	Entity: Global(55,72,0) Local(3,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# ...
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(63,76,0) Local(3,12,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(59,79,0) Local(3,15,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(66,77,0) Local(2,13,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(60,77,0) Local(0,13,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(67,77,0) Local(3,13,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(69,74,0) Local(1,10,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(61,77,0) Local(1,13,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(64,78,0) Local(0,14,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(70,74,0) Local(2,10,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(62,77,0) Local(2,13,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(65,78,0) Local(1,14,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,74,0) Local(3,10,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x3000000005108
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,74,0) Local(3,10,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !48, !tbaa !49
# 	At line 71 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(63,77,0) Local(3,13,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(66,78,0) Local(2,14,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(68,75,0) Local(0,11,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(67,78,0) Local(3,14,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(60,78,0) Local(0,14,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(69,75,0) Local(1,11,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(64,79,0) Local(0,15,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(70,75,0) Local(2,11,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(61,78,0) Local(1,14,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(65,79,0) Local(1,15,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,75,0) Local(3,11,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x300000000510c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,75,0) Local(3,11,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !48, !tbaa !49
# 	At line 71 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(62,78,0) Local(2,14,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(66,79,0) Local(2,15,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(68,76,0) Local(0,12,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(63,78,0) Local(3,14,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(67,79,0) Local(3,15,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(69,76,0) Local(1,12,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(60,79,0) Local(0,15,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(70,76,0) Local(2,12,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,76,0) Local(3,12,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(61,79,0) Local(1,15,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x3000000005110
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,76,0) Local(3,12,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !48, !tbaa !49
# 	At line 71 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(68,77,0) Local(0,13,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(62,79,0) Local(2,15,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(69,77,0) Local(1,13,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(63,79,0) Local(3,15,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(70,77,0) Local(2,13,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,77,0) Local(3,13,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x3000000005114
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,77,0) Local(3,13,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !48, !tbaa !49
# 	At line 71 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(68,78,0) Local(0,14,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(69,78,0) Local(1,14,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(70,78,0) Local(2,14,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,78,0) Local(3,14,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x3000000005118
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,78,0) Local(3,14,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !48, !tbaa !49
# 	At line 71 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(68,79,0) Local(0,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(69,79,0) Local(1,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(70,79,0) Local(2,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,79,0) Local(3,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !59, !tbaa !49
# 	At line 68 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x300000000511c
# 	Kernel: mat_mult_badmem
# 	Entity: Global(71,79,0) Local(3,15,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !48, !tbaa !49
# 	At line 71 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;

# %% [markdown]
# From the error messages we have very clear indications that both read and write memory access violations are taking place.

# %% [markdown]
# ### Interactive debugging with **Oclgrind**
#
# Oclgrind provides a powerful **gdb-like** debugging experience. The option **-i** allows for interactive line-by-line walkthroughs of kernels and we are going to step through each line of our buggy kernel.
#
# 1. Open a terminal and run oclgrind like this
# ```bash
# oclgrind -i ./mat_mult_badmem.exe
# ```
# 1. Within Oclgrind display all available commands using the **help** command
# ```bash
# help
# ```
# 1. Use the **next** command to step through the lines of the kernel arguments.
# 1. Use the **print** command to print out the value of the input variables **N0_C** and **N1_C**.
# ```bash
# print N0_C
# ```
# 1. Again use the print command to examine the value of buffer **B** at index 1. The value should be betwen 0 and 1.
# ```bash
# print B[1]
# ```
# 1. Get help on the **wi** command
# ```bash
# help wi
# ```
# 1. Move to work item (0, 72, 0) and type **continue** until you get a memory access violation
# ```bash
# wi 0 72 0
# continue
# ```
# 1. Print the value of **n**, **i0** and **i1** and locate in which array the memory read access violation occurred
# ```bash
# print n
# print i0
# print i1
# ```
# 1. Quit the application
# ```bash
# quit
# ```

# %% [markdown]
# ### Kernel-specific debugging
#
# Sometimes you might have one kernel to debug within a large program. If you only wish to debug a specific kernel without having to run an application there is the **oclgrind-kernel** application. It takes in a file specifying the runtime parameters and kernel arguments, and runs that kernel using the OpenCL device simulator. As follows is the contents of [mat_mult_badmem.sim](mat_mult_badmem.sim).
#
# ```bash
# kernels_mat_mult.c # File containing OpenCL program (can be OpenCL C or SPIR)
# mat_mult_badmem    # Name of the kernel to run
# 72 80 1     # NDRange
# 4 16 1      # Work-group size
#
# # First argument 'global float *A'
# # Alocation of 72*72*4 = 20736
# # bytes filled with 1's of type float
# <size=20736 fill=1 float>
#
# # Second argument 'global float *B'
# # Same size but filled with floats
# # in the range 0:5183 inclusive
# <size=20736 range=0:1:5183 float>
#
# # Third argument 'global float *C'
# # filled with zeros and type float
# <size=20736 fill=0 float>
#
# # Fourth argument integer N1_A
# <size=4 uint>
# 72
#
# # Fifth argument integer N0_C
# <size=4 uint>
# 72
#
# # Sixth argument integer N1_C
# <size=4 uint>
# 72
# ```

# %% [markdown]
# Running the simulation then takes the form
#
# ```bash
# oclgrind-kernel ./mat_mult_badmem.sim
# ```
#
# for memory access checks, and for interactive debugging we run
#
# ```bash
# oclgrind-kernel -i ./mat_mult_badmem.sim
# ```
#
# and proceed with debugging as before.

# %% [markdown]
# ## Vendor-specific tools

# %% [markdown]
# ### NVIDIA
#
# NVIDIA's OpenCL solution runs on NVIDIA hardware. While NVIDIA has very little explicit support for OpenCL in terms of development tools, their implemenation is mature and conformant with the latest 3.0 spec as well as having a significant number of accompanying examples. Debgugging tools for CUDA can provide insight into the processes at work on the GPU.
#
# #### Debugging with cuda-gdb
#
# Running the code under cuda-gdb is accompished with the command
#
# ```bash
# cuda-gdb --args ./mat_mult_badmem.exe -gpu
# ```
#
# Debugging on the host code can proceed as per normal but I haven't found a way to access the kernel. At the time of writing this tool didn't detect the memory access violations.
#
# #### Memory access checking with cuda-memcheck
#
# The CUDA memory checking tool **cuda-memcheck** is designed to check for race conditions, synchronisation errors, memory initialisation problems, and memory access violations. Memory checking works for both OpenCL and CUDA applications using the following call. We need to make sure we are using the NVIDIA compute device though.

# %%
# !cuda-memcheck ./mat_mult_badmem.exe -gpu 0
# Out:
# ========= CUDA-MEMCHECK
# ========= This tool is deprecated and will be removed in a future release of the CUDA toolkit
# ========= Please use the compute-sanitizer tool as a drop-in replacement
# 	               name: NVIDIA GeForce RTX 3060 Laptop GPU
# 	 global memory size: 6235 MB
# 	    max buffer size: 1558 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,15,0) in block (17,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,15,0) in block (17,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,15,0) in block (17,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,15,0) in block (17,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,14,0) in block (17,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,14,0) in block (17,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,14,0) in block (17,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,14,0) in block (17,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,13,0) in block (17,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,13,0) in block (17,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,13,0) in block (17,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,13,0) in block (17,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,12,0) in block (17,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,12,0) in block (17,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,12,0) in block (17,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,12,0) in block (17,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,11,0) in block (17,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,11,0) in block (17,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,11,0) in block (17,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,11,0) in block (17,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,10,0) in block (17,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,10,0) in block (17,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,10,0) in block (17,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,10,0) in block (17,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,9,0) in block (17,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,9,0) in block (17,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,9,0) in block (17,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,9,0) in block (17,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,8,0) in block (17,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,8,0) in block (17,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,8,0) in block (17,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,8,0) in block (17,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,15,0) in block (2,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,15,0) in block (2,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,15,0) in block (2,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,15,0) in block (2,4,0)
# =========     Address 0x7f8aa320a31c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,14,0) in block (2,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,14,0) in block (2,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,14,0) in block (2,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,14,0) in block (2,4,0)
# =========     Address 0x7f8aa320a318 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,13,0) in block (2,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,13,0) in block (2,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,13,0) in block (2,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,13,0) in block (2,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,12,0) in block (2,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,12,0) in block (2,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,12,0) in block (2,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,12,0) in block (2,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,11,0) in block (2,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,11,0) in block (2,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,11,0) in block (2,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,11,0) in block (2,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,10,0) in block (2,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,10,0) in block (2,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,10,0) in block (2,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,10,0) in block (2,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,9,0) in block (2,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,9,0) in block (2,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,9,0) in block (2,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,9,0) in block (2,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,8,0) in block (2,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,8,0) in block (2,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,8,0) in block (2,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# ...
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,13,0) in block (3,4,0)
# =========     Address 0x7f8aa320a314 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,12,0) in block (3,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,12,0) in block (3,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,12,0) in block (3,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,12,0) in block (3,4,0)
# =========     Address 0x7f8aa320a310 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,11,0) in block (3,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,11,0) in block (3,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,11,0) in block (3,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,11,0) in block (3,4,0)
# =========     Address 0x7f8aa320a30c is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,10,0) in block (3,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,10,0) in block (3,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,10,0) in block (3,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,10,0) in block (3,4,0)
# =========     Address 0x7f8aa320a308 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,9,0) in block (3,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,9,0) in block (3,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,9,0) in block (3,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,9,0) in block (3,4,0)
# =========     Address 0x7f8aa320a304 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (3,8,0) in block (3,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (2,8,0) in block (3,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (1,8,0) in block (3,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000dd0 in mat_mult_badmem
# =========     by thread (0,8,0) in block (3,4,0)
# =========     Address 0x7f8aa320a300 is out of bounds
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libnvidia-opencl.so.1 [0xed657]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libOpenCL.so.1 (clEnqueueNDRangeKernel + 0x3b) [0x954b]
# =========     Host Frame:./mat_mult_badmem.exe [0x4b2b]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 [0x29d90]
# =========     Host Frame:/usr/lib/x86_64-linux-gnu/libc.so.6 (__libc_start_main + 0x80) [0x29e40]
# =========     Host Frame:./mat_mult_badmem.exe [0x27e5]
# =========
# Error, Opencl call failed at "Waiting on the kernel" with error code CL_OUT_OF_RESOURCES (-5)
# ========= ERROR SUMMARY: 544 errors

# %% [markdown]
# We see that cuda-memcheck is catching the memory access error, but we don't have an in-depth look at what is happening in the kernel. Unfortunately the tool **cuda-memcheck** will soon be replaced by **compute-sanitizer**, however that application did not pick up the error at all.

# %%
# !compute-sanitizer --tool memcheck --padding 0 --target-processes all ./mat_mult_badmem.exe -gpu 0
# Out:
# ========= COMPUTE-SANITIZER
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024
# 	               name: gfx906:sramecc+:xnack-
# 	 global memory size: 17163 MB
# 	    max buffer size: 14588 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 256
# ========= Error: Target application terminated before first instrumented API call

# %% [markdown]
# ### AMD
#
# AMD has the **rocgdb** debugger available.
#
# ```bash
# rocgdb --args ./mat_mult_badmem.exe -gpu 1
# ```
#
# We set a breakpoint in the **mat_mult** kernel by typing this at the gdb command line
#
# ```gdb
# b mat_mult_badmem
# ```
#
# This is currently limited in usefulness until we can find a way to get the source code loaded.

# %% [markdown]
# ### Intel
#
# The [OneAPI toolkit](https://www.intel.com/content/www/us/en/developer/tools/oneapi/toolkits.html#base-kit) has an enhanced GDB debugger that has the ability to step through and debug OpenCL kernels. It works with the [Intel OpenCL runtime](https://www.intel.com/content/www/us/en/developer/articles/tool/opencl-drivers.html#cpu-section). Incidentally, the standard **GDB** debugger also works to debug kernels on the CPU runtime.
#
# #### Debugging with GDB
#
# In order to enable kernel debugging we need to select the Intel OpenCL CPU device set the following OpenCL build options at program compilation.
# ```bash
# -g -s /path/to/kernel.cl -cl-opt-disable
# ```
# The **"-s"** flag is to tell the runtime where the kernel source is and the **"-g"** is to enable debugging symbols. Both "-g" and "-s" flags appear to be Intel-specific compiler options and don't seem to work with other implementations. We set these options in the source file [mat_mult_badmem_gdb.cpp](mat_mult_badmem_gdb.cpp) as an additional argument to the **h_build_program** helper function.
#
# ```C++
#     // Turn this source code into a program
#     cl_program program = h_build_program(
#         kernel_source,
#         context,
#         device,
#         // Put debugging information here
#         // -g and -s flags are Intel-specifc
#         "-g -s kernels_mat_mult.c -cl-opt-disable"
#     );
# ```

# %% [markdown]
# Then we can run **gdb-oneapi** if you have the OneAPI toolkit (or just **gdb** if you don't) to start the program
#
# ```bash
# gdb-oneapi --args ./mat_mult_badmem_gdb.exe -cpu 0
# ```

# %% [markdown]
# Within the kernel there are three variables we can use to specify a breakpoint.
#
# * __ocl_dbg_gid0
# * __ocl_dbg_gid1
# * __ocl_dbg_gid2
#
# They represent the global id for dimensions 1, 2, and 3 during kernel execution. We can use these at gdb command line to set a specific breakpoint in the kernel. In this case we set execution to halt with when a kernel with **(__ocl_dbg_gid0 == 0) and (__ocl_dbg_gid1 == 72)** executes.
#
# ```bash
# break mat_mult_badmem if (__ocl_dbg_gid0 == 0) && (__ocl_dbg_gid1 == 72)
# ```
#
# Ignore the warning about shared library loading. The kernel source code is yet to be loaded. Now run the code
#
# ```bash
# run
# ```
#
# and it should stop at the correct work-item. We now have all the same debugging commands available as with Oclgrind and even new abilities such as being able to set variables.
#
# ```bash
# set temp=0
# ```
#
# Now enter
#
# ```bash
# quit
# ```
#
# to exit the program. I noticed that the Intel implementation didn't detect the memory error as a memory access violation.

# %% [markdown]
# <address>
# Written by Dr. Toby Potter of <a href="https://www.pelagos-consulting.com">Pelagos Consulting and Education</a> for the Pawsey Supercomputing Centre
# </address>
