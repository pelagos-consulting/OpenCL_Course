# %% [markdown]
# # Debugging OpenCL applications

# %%
import numpy as np

from matplotlib import pyplot as plt

# %matplotlib widget

# A is of size (NROWS_C, NCOLS_A)
# B is of size (NCOLS_A, NCOLS_C)    
# C is of size (NROWS_C, NCOLS_C)

NCOLS_A = 256
NROWS_C = 520
NCOLS_C = 1032

# Data type
dtype = np.float32

# Make up the arrays A, B, and C
A = np.random.random(size = (NROWS_C, NCOLS_A)).astype(dtype)
B = np.random.random(size = (NCOLS_A, NCOLS_C)).astype(dtype)

# Make up the answer
C = np.matmul(A, B, dtype = dtype)

# Write out the arrays as binary files
A.tofile("array_A.dat")
B.tofile("array_B.dat")

# %%
# !make clean; make; ./mat_mult_buggy.exe

# %%
# Import axes machinery
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Read in the output from OpenCL
C_ocl = np.fromfile("array_C.dat", dtype=dtype).reshape((NROWS_C, NCOLS_C))

# Make plots
fig, axes = plt.subplots(3, 1, figsize=(6,8), sharex=True, sharey=True)

# Data to plot
data = [C, C_ocl, np.abs(C-C_ocl)]

# Labels to plot
labels = ["Numpy", "OpenCL", "Absolute residual"]

for n, value in enumerate(data):
    # Plot the graph
    ax = axes[n]
    im = ax.imshow(value)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    # Set labels on things
    ax.set_xlabel("Dimension 1 (columns)")
    ax.set_ylabel("Dimension 0 (rows)")
    ax.set_title(labels[n])

    # Put a color bar on the plot
    plt.colorbar(mappable=im, cax=cax)

fig.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Debugging with printf

# %% [markdown]
# ## Debugging with GDB

# %% [markdown]
# ## Debugging and validation with OCLGrind

# %%
# !oclgrind ./mat_mult_buggy.exe
# Out:
# 	               name: Oclgrind Simulator
# 	 global memory size: 134 MB
# 	    max buffer size: 134 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 1024
#
# Invalid read of size 4 at global memory address 0x1000000082000
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082004
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082008
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008200c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082010
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082014
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082018
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008201c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082020
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082024
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082028
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008202c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082030
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082034
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082038
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008203c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082040
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082044
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082048
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008204c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082050
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082054
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082058
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008205c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082060
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082064
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082068
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008206c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082070
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082074
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082078
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008207c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082080
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082084
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082088
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008208c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082090
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082094
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082098
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008209c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820a0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820a4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820a8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820ac
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820b0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820b4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820b8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820bc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820c0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820c4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820c8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820cc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820d0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820d4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820d8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820dc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820e0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820e4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820e8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820ec
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820f0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820f4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820f8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000820fc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082100
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082104
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082108
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008210c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082110
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082114
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082118
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008211c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082120
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082124
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082128
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008212c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082130
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082134
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082138
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008213c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082140
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082144
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082148
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008214c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082150
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082154
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082158
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008215c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082160
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082164
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082168
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008216c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082170
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082174
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082178
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008217c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082180
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082184
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082188
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008218c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082190
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082194
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082198
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008219c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821a0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821a4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821a8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821ac
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821b0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821b4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821b8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821bc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821c0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821c4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821c8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821cc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821d0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821d4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821d8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821dc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821e0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821e4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821e8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821ec
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821f0
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821f4
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821f8
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000821fc
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082200
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082204
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082208
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008220c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082210
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082214
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082218
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008221c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082220
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082224
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082228
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008222c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082230
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082234
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082238
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008223c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082240
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082244
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082248
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008224c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082250
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082254
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082258
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008225c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082260
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082264
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082268
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008226c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082270
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082274
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082278
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008227c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082280
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082284
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082288
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000008228c
# 	Kernel: mat_mult
# 	Entity: Global(520,0,0) Local(8,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082290
# 	Kernel: mat_mult
# ...
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ebc
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ec0
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ec4
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ec8
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ecc
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ed0
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ed4
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ed8
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082edc
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ee0
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ee4
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ee8
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082eec
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ef0
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ef4
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082ef8
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082efc
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f00
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f04
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f08
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f0c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f10
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f14
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f18
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f1c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f20
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f24
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f28
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f2c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f30
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f34
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f38
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f3c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f40
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f44
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f48
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f4c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f50
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f54
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f58
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f5c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f60
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f64
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f68
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f6c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f70
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f74
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f78
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f7c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f80
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f84
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f88
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f8c
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000082f90
# 	Kernel: mat_mult
# 	Entity: Global(523,0,0) Local(11,0,0) Group(32,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 30 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Oclgrind: 1000 errors generated - suppressing further errors

# %% [markdown]
# ## Exercise
