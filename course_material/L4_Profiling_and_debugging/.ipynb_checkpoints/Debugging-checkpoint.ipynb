# %% [markdown]
# # Debugging OpenCL applications
#
# Debugging OpenCL applications has traditionally been a difficult topic. However there are some tools and techniques to help. These tools are:
#
# * Checking the error codes on every OpenCL call
# * Checking memory access from within kernels
# * Visual inspection of outputs
# * Using **printf** within kernels
# * Using **Oclgrind** to check memory access violations
#
# We will introduce an intentional bug into our matrix multiplication program and see if we can find it. In this instance we intentionally remove the guard check that protects the kernel from running off the end of buffer **C**. We choose the size of matrices **A**, **B**, and **C** to be (72,72) and a local size of (4,16)
#
# <figure style="margin-left:auto; margin-right:auto; width:80%;">
#     <img style="vertical-align:middle" src="../images/matrix_boundaries.svg">
#     <figcaption style= "text-align:lower; margin:1em; float:bottom; vertical-align:bottom;">Running off the end of the array due to differences between array size and global size.</figcaption>
# </figure>
#
#
# ```C++
# // kernels_mat_mult_badmem.c source
#
# // standard matrix multiply kernel
# __kernel void mat_mult (__global float* A,
#                         __global float* B,
#                         __global float* C,
#                         unsigned int N1_A,
#                         unsigned int N0_C,
#                         unsigned int N1_C) {
#
#     // C is of size (N0_C, N1_C)
#
#     // i0 and i1 represent the coordinates in Matrix C
#     // We assume row-major ordering for the matrices
#     size_t i0=get_global_id(0);
#     size_t i1=get_global_id(1);
#
#     // Scratch variable
#     float temp=0.0;
#
#     // Guard mechanism to make sure we do not go
#     // outside the boundaries of matrix C
#
#     // Comment out the guard mechanism
#     // to make sure we do not go
#     // outside the boundaries of matrix C
#
#     //if ((i0<N0_C) && (i1<N1_C)) {
#         // Loop over columns of A and rows of B
#         for (size_t n=0; n<N1_A; n++) {
#
#             // A is of size (N0_C, N1_A)
#             // B is of size (N1_A, N1_C)
#
#             // Loop across row i0 of A
#             // and down column i1 of B
#             temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#         }
#         // Number of rows in C is same as number of rows in A
#         C[i0*N1_C+i1]=temp;
#     //}
# }
# ```

# %% [markdown]
# ## Construct inputs
#
# As before we construct the arrays for input.

# %%
import numpy as np

from matplotlib import pyplot as plt

# %matplotlib widget

# A is of size (NROWS_C, NCOLS_A)
# B is of size (NCOLS_A, NCOLS_C)    
# C is of size (NROWS_C, NCOLS_C)

NCOLS_A = 72
NROWS_C = 72
NCOLS_C = 72

# Data type
dtype = np.float32

# Make up the arrays A, B, and C
A = np.random.random(size = (NROWS_C, NCOLS_A)).astype(dtype)
B = np.random.random(size = (NCOLS_A, NCOLS_C)).astype(dtype)

# Make up the answer
C = np.matmul(A, B, dtype = dtype)

# Write out the arrays as binary files
A.tofile("array_A.dat")
B.tofile("array_B.dat")

# %% [markdown]
# ## Run the buggy application

# %%
# !make clean; make; ./mat_mult_badmem.exe
# Out:
# rm -r *.exe
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult_badmem.cpp\
# 	-o mat_mult_badmem.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult_badmem.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult_badmem.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult.cpp\
# 	-o mat_mult.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult_memcheck.cpp\
# 	-o mat_mult_memcheck.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult_memcheck.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult_memcheck.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024
# 	               name: pthread-AMD Ryzen Threadripper 2950X 16-Core Processor
# 	 global memory size: 132854 MB
# 	    max buffer size: 34359 MB
# 	     max local size: (4096,4096,4096)
# 	     max work-items: 4096
# 	               name: gfx906:sramecc+:xnack-
# 	 global memory size: 17163 MB
# 	    max buffer size: 14588 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 256

# %% [markdown]
# Notice that with some OpenCL implementations the code completes without crashing. This is because some GPU-based opencl frameworks do not have accurate memory access violation checks. Thus small memory access violations result in undefined behaviour. CPU implementations are sensitive memory access violation checks and are more susceptible to memory access bugs than others.

# %% [markdown]
# ## Visual inspection of outputs

# %%
# Import axes machinery
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Read in the output from OpenCL
C_ocl = np.fromfile("array_C.dat", dtype=dtype).reshape((NROWS_C, NCOLS_C))

# Make plots
fig, axes = plt.subplots(3, 1, figsize=(6,8), sharex=True, sharey=True)

# Data to plot
data = [C, C_ocl, np.abs(C-C_ocl)]

# Labels to plot
labels = ["Numpy", "OpenCL", "Absolute residual"]

for n, value in enumerate(data):
    # Plot the graph
    ax = axes[n]
    im = ax.imshow(value)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    # Set labels on things
    ax.set_xlabel("Dimension 1 (columns)")
    ax.set_ylabel("Dimension 0 (rows)")
    ax.set_title(labels[n])

    # Put a color bar on the plot
    plt.colorbar(mappable=im, cax=cax)

fig.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Running off the end of the array is obvious in this instance because it affects the next row. That is why 8 cells are affected on the left hand side of the array.

# %% [markdown]
# ## Checking memory access
#
# When trying to get your OpenCL codes working it is helpful to first make sure that your memory accesses are valid. In this instance we change the kernel to [kernels_mat_mult_memcheck.c](kernels_mat_mult_memcheck.c) so that it puts into **C** the value of i1. Run the code and check the results by running the visual check above.

# %%
# !make; ./mat_mult_memcheck.exe
# Out:
# make: Nothing to be done for 'all'.
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024

# %% [markdown]
# ## Debugging with **printf**
#
# Some OpenCL implementations, in particular CPU ones, allow the use of a **printf** statement within a kernel.

# %% [markdown]
# ## Debugging with GDB

# %% [markdown]
# ## Debugging and validation with OCLGrind

# %%
# !oclgrind ./mat_mult_badmem.exe
# Out:
# 	               name: Oclgrind Simulator
# 	 global memory size: 134 MB
# 	    max buffer size: 134 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 1024
#
# Invalid read of size 4 at global memory address 0x1000000005100
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005104
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005108
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000510c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005110
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005114
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005118
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000511c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005120
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005124
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005128
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000512c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005130
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005134
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005138
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000513c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005140
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005144
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005148
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000514c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005150
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005154
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005158
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000515c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005160
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005164
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005168
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000516c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005170
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005174
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005178
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000517c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005180
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005184
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005188
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000518c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005190
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005194
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005198
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000519c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051a0
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051a4
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051a8
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051ac
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051b0
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051b4
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051b8
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051bc
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051c0
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051c4
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051c8
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051cc
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051d0
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051d4
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051d8
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051dc
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051e0
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051e4
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051e8
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051ec
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051f0
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051f4
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051f8
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000051fc
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005200
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005204
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005208
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000520c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005210
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005214
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005218
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000521c
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x3000000005100
# 	Kernel: mat_mult
# 	Entity: Global(72,0,0) Local(8,0,0) Group(4,0,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !46, !tbaa !47
# 	At line 35 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x1000000005220
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005224
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005228
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000522c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005230
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005234
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005238
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000523c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005240
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005244
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005248
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000524c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005250
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005254
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005258
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000525c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005260
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005264
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005268
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005100
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000526c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005104
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005270
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005108
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005274
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000510c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005278
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005110
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000527c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005280
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005114
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005118
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000511c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005120
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005124
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005128
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000512c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005130
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005134
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005138
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000513c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005140
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005144
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005148
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000514c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005150
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005284
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005288
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000528c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005290
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005294
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005298
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000529c
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052a0
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005100
# 	Kernel: mat_mult
# 	Entity: Global(72,1,0) Local(8,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005154
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005158
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000515c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005160
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005164
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005168
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000516c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005170
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005174
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005178
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000517c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005180
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005184
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005188
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000518c
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005100
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005104
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005108
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000510c
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005110
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005114
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005118
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005100
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052a4
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000511c
# 	Kernel: mat_mult
# 	Entity: Global(72,2,0) Local(8,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005104
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052a8
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005108
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052ac
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000510c
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052b0
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005110
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052b4
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005114
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052b8
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005118
# 	Kernel: mat_mult
# 	Entity: Global(72,5,0) Local(8,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052bc
# 	Kernel: mat_mult
# 	Entity: Global(73,0,0) Local(9,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005190
# 	Kernel: mat_mult
# 	Entity: Global(72,3,0) Local(8,0,0) Group(4,3,0)
# ...
#
#
# Invalid read of size 4 at global memory address 0x10000000052f0
# 	Kernel: mat_mult
# 	Entity: Global(73,5,0) Local(9,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052dc
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f4
# 	Kernel: mat_mult
# 	Entity: Global(73,5,0) Local(9,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052e0
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052b0
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052e4
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f8
# 	Kernel: mat_mult
# 	Entity: Global(73,5,0) Local(9,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052e8
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052b4
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052e4
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005104
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052e8
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005108
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005174
# 	Kernel: mat_mult
# 	Entity: Global(72,6,0) Local(8,0,0) Group(4,6,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052fc
# 	Kernel: mat_mult
# 	Entity: Global(73,5,0) Local(9,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005110
# 	Kernel: mat_mult
# 	Entity: Global(72,7,0) Local(8,0,0) Group(4,7,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052b8
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052ec
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052bc
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f0
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f4
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f8
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000510c
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052fc
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005110
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005300
# 	Kernel: mat_mult
# 	Entity: Global(73,5,0) Local(9,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005114
# 	Kernel: mat_mult
# 	Entity: Global(72,7,0) Local(8,0,0) Group(4,7,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005358
# 	Kernel: mat_mult
# 	Entity: Global(74,3,0) Local(10,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052c0
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052ec
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005560
# 	Kernel: mat_mult
# 	Entity: Global(75,0,0) Local(11,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005178
# 	Kernel: mat_mult
# 	Entity: Global(72,6,0) Local(8,0,0) Group(4,6,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005300
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000517c
# 	Kernel: mat_mult
# 	Entity: Global(72,6,0) Local(8,0,0) Group(4,6,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005304
# 	Kernel: mat_mult
# 	Entity: Global(73,4,0) Local(9,0,0) Group(4,4,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005304
# 	Kernel: mat_mult
# 	Entity: Global(73,5,0) Local(9,0,0) Group(4,5,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005118
# 	Kernel: mat_mult
# 	Entity: Global(72,7,0) Local(8,0,0) Group(4,7,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000535c
# 	Kernel: mat_mult
# 	Entity: Global(74,3,0) Local(10,0,0) Group(4,3,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052c4
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f0
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052c8
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052f4
# 	Kernel: mat_mult
# 	Entity: Global(73,2,0) Local(9,0,0) Group(4,2,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005114
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005180
# 	Kernel: mat_mult
# 	Entity: Global(72,6,0) Local(8,0,0) Group(4,6,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005118
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005184
# 	Kernel: mat_mult
# 	Entity: Global(72,6,0) Local(8,0,0) Group(4,6,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000511c
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005188
# 	Kernel: mat_mult
# 	Entity: Global(72,6,0) Local(8,0,0) Group(4,6,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x100000000511c
# 	Kernel: mat_mult
# 	Entity: Global(72,7,0) Local(8,0,0) Group(4,7,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005120
# 	Kernel: mat_mult
# 	Entity: Global(72,8,0) Local(8,0,0) Group(4,8,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052cc
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005564
# 	Kernel: mat_mult
# 	Entity: Global(75,0,0) Local(11,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052d0
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x1000000005568
# 	Kernel: mat_mult
# 	Entity: Global(75,0,0) Local(11,0,0) Group(4,0,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x10000000052d4
# 	Kernel: mat_mult
# 	Entity: Global(73,1,0) Local(9,0,0) Group(4,1,0)
# 	  %0 = load float, float addrspace(1)* %arrayidx, align 4, !dbg !54, !tbaa !47
# 	At line 32 (column 19) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Oclgrind: 1000 errors generated - suppressing further errors

# %% [markdown]
# ## Exercise
