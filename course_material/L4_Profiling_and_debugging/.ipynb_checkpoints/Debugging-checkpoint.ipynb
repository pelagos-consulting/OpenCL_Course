# %% [markdown]
# # Debugging OpenCL applications
#
# Debugging OpenCL applications has traditionally been a difficult topic. However there are some tools and techniques to help. These tools are:
#
# * Checking the error codes on every OpenCL call
# * Checking memory access from within kernels
# * Visual inspection of outputs
# * Using **printf** within kernels
# * Using **Oclgrind** to check memory access violations
#
# We will introduce an **intentional bug** into our matrix multiplication program and see if we can find it. In this instance we intentionally remove the guard check that protects the kernel from running off the end of buffer **C**. The size of matrices **A**, **B**, and **C** have chosen to be (72,72) with a local size of (4,16). Along dimension 0 an exact number of workgroups (18) can fit into the desired local size of 72. However, along dimension 1 the global size must be increased to 80 in order for an integer number of workgroups to fit. If we do not have a guard in place then array accesses into the matrices will run off the ends, resulting in a memory access violation.
#
# <figure style="margin-left:auto; margin-right:auto; width:80%;">
#     <img style="vertical-align:middle" src="../images/matrix_boundaries.svg">
#     <figcaption style= "text-align:lower; margin:1em; float:bottom; vertical-align:bottom;">Running off the end of the array due to differences between array size and global size.</figcaption>
# </figure>
#
# ```C++
# // kernels_mat_mult_badmem.c source
#
# // standard matrix multiply kernel
# __kernel void mat_mult (__global float* A,
#                         __global float* B,
#                         __global float* C,
#                         unsigned int N1_A,
#                         unsigned int N0_C,
#                         unsigned int N1_C) {
#
#     // C is of size (N0_C, N1_C)
#
#     // i0 and i1 represent the coordinates in Matrix C
#     // We assume row-major ordering for the matrices
#     size_t i0=get_global_id(0);
#     size_t i1=get_global_id(1);
#
#     // Scratch variable
#     float temp=0.0;
#
#     // Guard mechanism to make sure we do not go
#     // outside the boundaries of matrix C
#
#     // Comment out the guard mechanism
#     // to make sure we do not go
#     // outside the boundaries of matrix C
#
#     //if ((i0<N0_C) && (i1<N1_C)) {
#         // Loop over columns of A and rows of B
#         for (size_t n=0; n<N1_A; n++) {
#
#             // A is of size (N0_C, N1_A)
#             // B is of size (N1_A, N1_C)
#
#             // Loop across row i0 of A
#             // and down column i1 of B
#             temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#         }
#         // Number of rows in C is same as number of rows in A
#         C[i0*N1_C+i1]=temp;
#     //}
# }
# ```

# %% [markdown]
# ## Construct inputs
#
# As before we construct the arrays for input.

# %%
import numpy as np

from matplotlib import pyplot as plt

# %matplotlib widget

# A is of size (NROWS_C, NCOLS_A)
# B is of size (NCOLS_A, NCOLS_C)    
# C is of size (NROWS_C, NCOLS_C)

NCOLS_A = 72
NROWS_C = 72
NCOLS_C = 72

# Data type
dtype = np.float32

# Make up the arrays A, B, and C
A = np.random.random(size = (NROWS_C, NCOLS_A)).astype(dtype)
B = np.random.random(size = (NCOLS_A, NCOLS_C)).astype(dtype)

# Make up the answer
C = np.matmul(A, B, dtype = dtype)

# Write out the arrays as binary files
A.tofile("array_A.dat")
B.tofile("array_B.dat")

# %% [markdown]
# ## Run the buggy application

# %%
# !make clean; make; ./mat_mult_badmem.exe
# Out:
# rm -r *.exe
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult_badmem.cpp\
# 	-o mat_mult_badmem.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult_badmem.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult_badmem.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult.cpp\
# 	-o mat_mult.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult_memcheck.cpp\
# 	-o mat_mult_memcheck.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult_memcheck.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult_memcheck.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult_printf.cpp\
# 	-o mat_mult_printf.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult_printf.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult_printf.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# g++ -std=c++11 -g -O2 -fopenmp -I/usr/local/cuda/include -I../include -L/usr/local/cuda/lib64 mat_mult_badmem_gdb.cpp\
# 	-o mat_mult_badmem_gdb.exe -lOpenCL -lomp
# In file included from ../include/cl_helper.hpp:10,
#                  from mat_mult_badmem_gdb.cpp:16:
# /usr/local/cuda/include/CL/cl.hpp:5085:28: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#  5085 |         VECTOR_CLASS<cl_int>* binaryStatus = NULL,
#       |                            ^
# In file included from mat_mult_badmem_gdb.cpp:16:
# ../include/cl_helper.hpp:16:29: warning: ignoring attributes on template argument ‘cl_int’ {aka ‘int’} [-Wignored-attributes]
#    16 | std::map<cl_int, const char*> error_codes {
#       |                             ^
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024
# 	               name: pthread-AMD Ryzen Threadripper 2950X 16-Core Processor
# 	 global memory size: 132854 MB
# 	    max buffer size: 34359 MB
# 	     max local size: (4096,4096,4096)
# 	     max work-items: 4096
# 	               name: gfx906:sramecc+:xnack-
# 	 global memory size: 17163 MB
# 	    max buffer size: 14588 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 256
# 	               name: AMD Ryzen Threadripper 2950X 16-Core Processor
# 	 global memory size: 135002 MB
# 	    max buffer size: 33750 MB
# 	     max local size: (8192,8192,8192)
# 	     max work-items: 8192

# %% [markdown]
# Notice that with some OpenCL implementations the code completes without crashing. This is because some OpenCL frameworks (GPU ones in particular) do not have accurate memory access violation checks. Memory access violations can result in undefined behaviour. Due to OS security, CPU implementations are more sensitive to memory access violations than others. This means CPU-based implementations are better to develop with.

# %% [markdown]
# ## Visual inspection of outputs

# %%
# Import axes machinery
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Read in the output from OpenCL
C_ocl = np.fromfile("array_C.dat", dtype=dtype).reshape((NROWS_C, NCOLS_C))

# Make plots
fig, axes = plt.subplots(3, 1, figsize=(6,8), sharex=True, sharey=True)

# Data to plot
data = [C, C_ocl, np.abs(C-C_ocl)]

# Labels to plot
labels = ["Numpy", "OpenCL", "Absolute residual"]

for n, value in enumerate(data):
    # Plot the graph
    ax = axes[n]
    im = ax.imshow(value)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    # Set labels on things
    ax.set_xlabel("Dimension 1 (columns)")
    ax.set_ylabel("Dimension 0 (rows)")
    ax.set_title(labels[n])

    # Put a color bar on the plot
    plt.colorbar(mappable=im, cax=cax)

fig.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Running off the end of the array is obvious in this instance because it affects the first 8 cells of next row. That is why 8 cells are affected on the left hand side of the array.

# %% [markdown]
# ## Checking memory access
#
# When trying to get your OpenCL codes working it is helpful to first make sure that your memory accesses are valid. In this instance we change the kernel to [kernels_mat_mult_memcheck.c](kernels_mat_mult_memcheck.c) so that it fills **C** with a known value. In this case we fill it with **i1**. Run the code and check the results by running the visual check above.

# %%
# !make; ./mat_mult_memcheck.exe
# Out:
# make: Nothing to be done for 'all'.
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024

# %% [markdown]
# Some lines are filled with higher values of **i1** whereas others are filled with lower values. This shows that one cannot rely on the order in which workgroups complete and the order in which memory adjustments are flushed back to global memory.

# %% [markdown]
# ## Debugging with **printf**
#
# Some OpenCL implementations, in particular CPU ones, allow the use of a **printf** statement within a kernel. We edit the kernel source in file [kernels_mat_mult_printf.c](kernels_mat_mult_printf.c) to include a printf statement that triggers whenever we exceed the size of the matrices along dimension 1.
#
# ```C
# // standard matrix multiply kernel
# __kernel void mat_mult (__global float* A,
#                         __global float* B,
#                         __global float* C,
#                         unsigned int N1_A,
#                         unsigned int N0_C,
#                         unsigned int N1_C) {
#
#     // C is of size (N0_C, N1_C)
#
#     // i0 and i1 represent the coordinates in Matrix C
#     // We assume row-major ordering for the matrices
#     size_t i0=get_global_id(0);
#     size_t i1=get_global_id(1);
#
#     // Scratch variable
#     float temp=0.0;
#
#     // Comment out the guard mechanism
#     // to make sure we do not go
#     // outside the boundaries of matrix C
#     if (i1>N1_C-1) {
#         printf("i1 is %d\n", i1);
#     }
#
#     //if ((i0<N0_C) && (i1<N1_C)) {
#         // Loop over columns of A and rows of B
#         for (size_t n=0; n<N1_A; n++) {
#
#             // A is of size (N0_C, N1_A)
#             // B is of size (N1_A, N1_C)
#
#             // Loop across row i0 of A
#             // and down column i1 of B
#             temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#         }
#         // Number of rows in C is same as number of rows in A
#         C[i0*N1_C+i1]=temp;
#     //}
# }
# ```

# %% [markdown]
# Now run the program and observe that the workgroups do indeed encounter values of **i1** that go beyond the bounds of the array.

# %%
# !make; ./mat_mult_printf.exe
# Out:
# make: Nothing to be done for 'all'.
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024
# i1 is 72
# i1 is 73
# i1 is 74
# i1 is 75
# i1 is 76
# i1 is 77
# i1 is 78
# i1 is 79

# %% [markdown]
# ## Debugging and validation with Oclgrind
#
# [Oclgrind](https://github.com/jrprice/Oclgrind) simulates an OpenCL device that self-checks for data races, memory access violations, and erroneous API runtime calls. It currently provides an OpenCL 1.2 interface as well as **gdb-like** interactive kernel debugging. Oclgrind is exactly what the OpenCL community needs for interactive debugging of kernels, however it is **orders of magnitude** slower than a native OpenCL application, so you need to make problem sizes really small, as we have done, or you can have a setting **-q** to just compute the first and last workgroups.

# %% [markdown]
# ### Memory access checking
#
# If you run **oclgrind** with the application as an argument then it intercepts OpenCL library calls that the application makes, and provides a sole OpenCL device that checks for errors.

# %%
# !oclgrind ./mat_mult_badmem.exe
# Out:
# 	               name: Oclgrind Simulator
# 	 global memory size: 134 MB
# 	    max buffer size: 134 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 1024
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(40,72,0) Local(0,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(56,72,0) Local(0,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(60,72,0) Local(0,8,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(64,72,0) Local(0,8,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(41,72,0) Local(1,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(61,72,0) Local(1,8,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(57,72,0) Local(1,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(65,72,0) Local(1,8,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(42,72,0) Local(2,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(62,72,0) Local(2,8,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(58,72,0) Local(2,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(66,72,0) Local(2,8,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(43,72,0) Local(3,8,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(63,72,0) Local(3,8,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(59,72,0) Local(3,8,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(67,72,0) Local(3,8,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(40,73,0) Local(0,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(60,73,0) Local(0,9,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(56,73,0) Local(0,9,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(64,73,0) Local(0,9,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(41,73,0) Local(1,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(61,73,0) Local(1,9,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(57,73,0) Local(1,9,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(42,73,0) Local(2,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(65,73,0) Local(1,9,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(62,73,0) Local(2,9,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(58,73,0) Local(2,9,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(43,73,0) Local(3,9,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(66,73,0) Local(2,9,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(63,73,0) Local(3,9,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(59,73,0) Local(3,9,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(40,74,0) Local(0,10,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(67,73,0) Local(3,9,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(60,74,0) Local(0,10,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(0,72,0) Local(0,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(56,74,0) Local(0,10,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(4,72,0) Local(0,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(41,74,0) Local(1,10,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(64,74,0) Local(0,10,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(61,74,0) Local(1,10,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(57,74,0) Local(1,10,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(1,72,0) Local(1,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(42,74,0) Local(2,10,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(62,74,0) Local(2,10,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(65,74,0) Local(1,10,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(5,72,0) Local(1,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(58,74,0) Local(2,10,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(8,72,0) Local(0,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(43,74,0) Local(3,10,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(63,74,0) Local(3,10,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(66,74,0) Local(2,10,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(2,72,0) Local(2,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(59,74,0) Local(3,10,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(12,72,0) Local(0,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(6,72,0) Local(2,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(40,75,0) Local(0,11,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(9,72,0) Local(1,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(60,75,0) Local(0,11,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(16,72,0) Local(0,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(20,72,0) Local(0,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(56,75,0) Local(0,11,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(67,74,0) Local(3,10,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(3,72,0) Local(3,8,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(41,75,0) Local(1,11,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(28,72,0) Local(0,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(13,72,0) Local(1,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(24,72,0) Local(0,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(61,75,0) Local(1,11,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(7,72,0) Local(3,8,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(57,75,0) Local(1,11,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(64,75,0) Local(0,11,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(32,72,0) Local(0,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(10,72,0) Local(2,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(17,72,0) Local(1,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(21,72,0) Local(1,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(42,75,0) Local(2,11,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(62,75,0) Local(2,11,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(0,73,0) Local(0,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(36,72,0) Local(0,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(58,75,0) Local(2,11,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(44,72,0) Local(0,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(14,72,0) Local(2,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(29,72,0) Local(1,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(25,72,0) Local(1,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(65,75,0) Local(1,11,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(4,73,0) Local(0,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(43,75,0) Local(3,11,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(33,72,0) Local(1,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(11,72,0) Local(3,8,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(63,75,0) Local(3,11,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(18,72,0) Local(2,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(48,72,0) Local(0,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(22,72,0) Local(2,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(59,75,0) Local(3,11,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(52,72,0) Local(0,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(66,75,0) Local(2,11,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(1,73,0) Local(1,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(37,72,0) Local(1,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(45,72,0) Local(1,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(40,76,0) Local(0,12,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(30,72,0) Local(2,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(15,72,0) Local(3,8,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(26,72,0) Local(2,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(60,76,0) Local(0,12,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(5,73,0) Local(1,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(56,76,0) Local(0,12,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(34,72,0) Local(2,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(8,73,0) Local(0,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(19,72,0) Local(3,8,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(23,72,0) Local(3,8,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000510c
# 	Kernel: mat_mult
# 	Entity: Global(67,75,0) Local(3,11,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(49,72,0) Local(1,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(53,72,0) Local(1,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(41,76,0) Local(1,12,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(61,76,0) Local(1,12,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(2,73,0) Local(2,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(38,72,0) Local(2,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(46,72,0) Local(2,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(57,76,0) Local(1,12,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(12,73,0) Local(0,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(31,72,0) Local(3,8,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(27,72,0) Local(3,8,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(6,73,0) Local(2,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(64,76,0) Local(0,12,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(42,76,0) Local(2,12,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(35,72,0) Local(3,8,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(68,72,0) Local(0,8,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(62,76,0) Local(2,12,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(9,73,0) Local(1,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(16,73,0) Local(0,9,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(20,73,0) Local(0,9,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(50,72,0) Local(2,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(54,72,0) Local(2,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(58,76,0) Local(2,12,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(3,73,0) Local(3,9,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(39,72,0) Local(3,8,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(47,72,0) Local(3,8,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(28,73,0) Local(0,9,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(13,73,0) Local(1,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(24,73,0) Local(0,9,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(43,76,0) Local(3,12,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(63,76,0) Local(3,12,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(65,76,0) Local(1,12,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(7,73,0) Local(3,9,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(59,76,0) Local(3,12,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(10,73,0) Local(2,9,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(32,73,0) Local(0,9,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(69,72,0) Local(1,8,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(17,73,0) Local(1,9,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(21,73,0) Local(1,9,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(51,72,0) Local(3,8,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005100
# 	Kernel: mat_mult
# 	Entity: Global(55,72,0) Local(3,8,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult
# 	Entity: Global(60,77,0) Local(0,13,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult
# 	Entity: Global(40,77,0) Local(0,13,0) Group(10,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005110
# 	Kernel: mat_mult
# 	Entity: Global(66,76,0) Local(2,12,0) Group(16,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(0,74,0) Local(0,10,0) Group(0,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(36,73,0) Local(0,9,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(44,73,0) Local(0,9,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult
# 	Entity: Global(56,77,0) Local(0,13,0) Group(14,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(25,73,0) Local(1,9,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(14,73,0) Local(2,9,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005104
# 	Kernel: mat_mult
# 	Entity: Global(29,73,0) Local(1,9,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005108
# 	Kernel: mat_mult
# 	Entity: Global(4,74,0) Local(0,10,0) Group(1,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005114
# 	Kernel: mat_mult
# 	Entity: Global(61,77,0) Local(1,13,0) Group(15,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# ...
# 	Kernel: mat_mult
# 	Entity: Global(13,79,0) Local(1,15,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(26,79,0) Local(2,15,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(34,79,0) Local(2,15,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(28,79,0) Local(0,15,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(51,78,0) Local(3,14,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(8,79,0) Local(0,15,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(23,78,0) Local(3,14,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(53,78,0) Local(1,14,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(71,78,0) Local(3,14,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x3000000005118
# 	Kernel: mat_mult
# 	Entity: Global(71,78,0) Local(3,14,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !46, !tbaa !47
# 	At line 35 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(16,79,0) Local(0,15,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(14,79,0) Local(2,15,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(38,78,0) Local(2,14,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(27,79,0) Local(3,15,0) Group(6,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(46,78,0) Local(2,14,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(29,79,0) Local(1,15,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(48,79,0) Local(0,15,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(9,79,0) Local(1,15,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(35,79,0) Local(3,15,0) Group(8,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(68,79,0) Local(0,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(17,79,0) Local(1,15,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(15,79,0) Local(3,15,0) Group(3,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(20,79,0) Local(0,15,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(54,78,0) Local(2,14,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(30,79,0) Local(2,15,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(49,79,0) Local(1,15,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(10,79,0) Local(2,15,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(39,78,0) Local(3,14,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(47,78,0) Local(3,14,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(18,79,0) Local(2,15,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(69,79,0) Local(1,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(31,79,0) Local(3,15,0) Group(7,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(21,79,0) Local(1,15,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(50,79,0) Local(2,15,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(11,79,0) Local(3,15,0) Group(2,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x2000000005118
# 	Kernel: mat_mult
# 	Entity: Global(55,78,0) Local(3,14,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(19,79,0) Local(3,15,0) Group(4,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(70,79,0) Local(2,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(36,79,0) Local(0,15,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(44,79,0) Local(0,15,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(51,79,0) Local(3,15,0) Group(12,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(71,79,0) Local(3,15,0) Group(17,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid write of size 4 at global memory address 0x300000000511c
# 	Kernel: mat_mult
# 	Entity: Global(71,79,0) Local(3,15,0) Group(17,4,0)
# 	  store float %temp.0, float addrspace(1)* %arrayidx12, align 4, !dbg !46, !tbaa !47
# 	At line 35 (column 22) of input.cl:
# 	  C[i0*N1_C+i1]=temp;
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(22,79,0) Local(2,15,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(52,79,0) Local(0,15,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(37,79,0) Local(1,15,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(45,79,0) Local(1,15,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(23,79,0) Local(3,15,0) Group(5,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(53,79,0) Local(1,15,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(38,79,0) Local(2,15,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(46,79,0) Local(2,15,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(39,79,0) Local(3,15,0) Group(9,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(54,79,0) Local(2,15,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(47,79,0) Local(3,15,0) Group(11,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];
#
#
# Invalid read of size 4 at global memory address 0x200000000511c
# 	Kernel: mat_mult
# 	Entity: Global(55,79,0) Local(3,15,0) Group(13,4,0)
# 	  %1 = load float, float addrspace(1)* %arrayidx7, align 4, !dbg !57, !tbaa !47
# 	At line 32 (column 32) of input.cl:
# 	  temp+=A[i0*N1_A+n]*B[n*N1_C+i1];

# %% [markdown]
# From the error messages we have very clear indications that both read and write memory access violations are taking place.

# %% [markdown]
# ### Interactive debugging with **Oclgrind**
#
# Oclgrind provides a powerful **gdb-like** debugging experience. The option **-i** allows for interactive line-by-line walkthroughs of kernels and we are going to step through each line of our buggy kernel.
#
# 1. Open a terminal and run oclgrind like this
# ```bash
# oclgrind -i ./mat_mult_badmem.exe
# ```
# 1. Within Oclgrind display all available commands using the **help** command
# ```bash
# help
# ```
# 1. Use the **next** command to step through the lines of the kernel arguments.
# 1. Use the **print** command to print out the value of the input variables **N0_C** and **N1_C**.
# ```bash
# print N0_C
# ```
# 1. Again use the print command to examine the value of buffer **B** at index 1. The value should be betwen 0 and 1.
# ```bash
# print B[1]
# ```
# 1. Get help on the **wi** command
# ```bash
# help wi
# ```
# 1. Move to work item (0, 72, 0) and **continue** until you get a memory access violation
# ```bash
# wi 0 72 0
# continue
# ```
# 1. Print the value of **n**, **i0** and **i1** and locate in which array the memory read access violation occurred
# ```bash
# print n
# print i0
# print i1
# ```
# 1. Quit the application
# ```bash
# quit
# ```

# %% [markdown]
# ### Kernel-specific debugging
#
# Sometimes you might have one kernel to debug within a large program. If you only wish to debug a specific kernel without having to run an application there is the **oclgrind-kernel** application. It takes in a file specifying the runtime parameters and kernel arguments, and runs that kernel using the OpenCL device simulator. As follows is the contents of [mat_mult_badmem.sim](mat_mult_badmem.sim).
#
# ```bash
# kernels_mat_mult_badmem.c # File containing OpenCL program (can be OpenCL C or SPIR)
# mat_mult    # Name of the kernel to run
# 72 80 1     # NDRange
# 4 16 1      # Work-group size
#
# # First argument 'global float *A'
# # Alocation of 72*72*4 = 20736
# # bytes filled with 1's of type float
# <size=20736 fill=1 float>
#
# # Second argument 'global float *B'
# # Same size but filled with floats
# # in the range 0:5183 inclusive
# <size=20736 range=0:1:5183 float>
#
# # Third argument 'global float *C'
# # filled with zeros and type float
# <size=20736 fill=0 float>
#
# # Fourth argument integer N1_A
# <size=4 uint>
# 72
#
# # Fifth argument integer N0_C
# <size=4 uint>
# 72
#
# # Sixth argument integer N1_C
# <size=4 uint>
# 72
# ```

# %% [markdown]
# Running the simulation then takes the form
#
# ```bash
# oclgrid-kernel ./mat_mult_badmem.exe
# ```
#
# for memory access checks, and
#
# ```bash
# oclgrid-kernel -i ./mat_mult_badmem.exe
# ```
#
# for interactive debugging as before.

# %% [markdown]
# ## Vendor-specific tools

# %% [markdown]
# ### NVIDIA
#
# NVIDIA has
#
# #### cuda-gdb
#
# #### cuda-memcheck

# %%
# !/usr/local/cuda/bin/cuda-memcheck ./mat_mult_badmem_gdb.exe
# Out:
# ========= CUDA-MEMCHECK
# 	               name: NVIDIA GeForce RTX 3060
# 	 global memory size: 12636 MB
# 	    max buffer size: 3159 MB
# 	     max local size: (1024,1024,64)
# 	     max work-items: 1024
# 	               name: pthread-AMD Ryzen Threadripper 2950X 16-Core Processor
# 	 global memory size: 132854 MB
# 	    max buffer size: 34359 MB
# 	     max local size: (4096,4096,4096)
# 	     max work-items: 4096
# 	               name: gfx906:sramecc+:xnack-
# 	 global memory size: 17163 MB
# 	    max buffer size: 14588 MB
# 	     max local size: (1024,1024,1024)
# 	     max work-items: 256
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,15,0) in block (11,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,15,0) in block (11,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,15,0) in block (11,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,15,0) in block (11,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,14,0) in block (11,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,14,0) in block (11,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,14,0) in block (11,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,14,0) in block (11,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,13,0) in block (11,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,13,0) in block (11,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,13,0) in block (11,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,13,0) in block (11,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,12,0) in block (11,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,12,0) in block (11,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,12,0) in block (11,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,12,0) in block (11,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,11,0) in block (11,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,11,0) in block (11,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,11,0) in block (11,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,11,0) in block (11,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,10,0) in block (11,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,10,0) in block (11,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,10,0) in block (11,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,10,0) in block (11,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,9,0) in block (11,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,9,0) in block (11,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,9,0) in block (11,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,9,0) in block (11,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,8,0) in block (11,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,8,0) in block (11,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,8,0) in block (11,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,8,0) in block (11,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,15,0) in block (10,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,15,0) in block (10,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,15,0) in block (10,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,15,0) in block (10,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,14,0) in block (10,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,14,0) in block (10,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,14,0) in block (10,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,14,0) in block (10,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,13,0) in block (10,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,13,0) in block (10,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,13,0) in block (10,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,13,0) in block (10,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,12,0) in block (10,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,12,0) in block (10,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,12,0) in block (10,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,12,0) in block (10,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,11,0) in block (10,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,11,0) in block (10,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,11,0) in block (10,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,11,0) in block (10,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,10,0) in block (10,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,10,0) in block (10,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,10,0) in block (10,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,10,0) in block (10,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,9,0) in block (10,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,9,0) in block (10,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,9,0) in block (10,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,9,0) in block (10,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,8,0) in block (10,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,8,0) in block (10,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,8,0) in block (10,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,8,0) in block (10,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,15,0) in block (9,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,15,0) in block (9,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,15,0) in block (9,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,15,0) in block (9,4,0)
# =========     Address 0x7fc2f060a31c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,14,0) in block (9,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,14,0) in block (9,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,14,0) in block (9,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,14,0) in block (9,4,0)
# =========     Address 0x7fc2f060a318 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,13,0) in block (9,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# ...
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,13,0) in block (12,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,13,0) in block (12,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,13,0) in block (12,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,13,0) in block (12,4,0)
# =========     Address 0x7fc2f060a314 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,12,0) in block (12,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,12,0) in block (12,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,12,0) in block (12,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,12,0) in block (12,4,0)
# =========     Address 0x7fc2f060a310 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,11,0) in block (12,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,11,0) in block (12,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,11,0) in block (12,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,11,0) in block (12,4,0)
# =========     Address 0x7fc2f060a30c is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,10,0) in block (12,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,10,0) in block (12,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,10,0) in block (12,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,10,0) in block (12,4,0)
# =========     Address 0x7fc2f060a308 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,9,0) in block (12,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,9,0) in block (12,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,9,0) in block (12,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,9,0) in block (12,4,0)
# =========     Address 0x7fc2f060a304 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (3,8,0) in block (12,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (2,8,0) in block (12,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (1,8,0) in block (12,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# ========= Invalid __global__ read of size 4
# =========     at 0x00000de0 in mat_mult
# =========     by thread (0,8,0) in block (12,4,0)
# =========     Address 0x7fc2f060a300 is out of bounds
# =========     Device Frame:mat_mult (mat_mult : 0xde0)
# =========     Saved host backtrace up to driver entry point at kernel launch time
# =========     Host Frame:/lib64/libnvidia-opencl.so.1 [0x169ed1]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x28cf]
# =========     Host Frame:/lib64/libc.so.6 [0x2d540]
# =========     Host Frame:/lib64/libc.so.6 (__libc_start_main + 0x7c) [0x2d5ec]
# =========     Host Frame:./mat_mult_badmem_gdb.exe [0x2a45]
# =========
# Error, Opencl call failed at "Waiting on the kernel" with error code CL_OUT_OF_RESOURCES (-5)
# ========= ERROR SUMMARY: 480 errors

# %%
# !cuda-gdb ./mat_mult_badmem.exe
# Out:
# /bin/bash: line 1: cuda-gdb: command not found

# %% [markdown]
# ### AMD

# %% [markdown]
# ### INTEL

# %% [markdown]
# ## Exercise
